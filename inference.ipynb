# %% [markdown]
# # HW4 Inference
# Student Info: 112550169 潘仰祐

# %% [markdown]
# ## 1. Environment Setup
# Please follow the steps below to make an environment.

# %% [markdown]
# ### Step 0: Change the Runtime Type
# Click the downwards triangle entitiled by "Additional Connection Options" and select "T4 GPU" as the hardware accelerator, and "2025.10" as the runtime version. Below is a test code, and the expected output is
# ```
# CUDA Version        : 12.4
# Python 3.12.12
# ```
#
# ref: [Google Colab Backend Versions]( https://github.com/googlecolab/backend-info/blob/39a418f03348f1f95c761a173b8bace8184970bb/README.md#202510 )
#
# If there is any version issue, please install the exact version of python with `apt` command. The cuda version is not that important on Google Colab (the limit from Nvidia is more loose for Commercial GPUs).

# %%
# !nvidia-smi --version | grep CUDA
# !python3 --version

# %% [markdown]
# ### Step 1: Import the codes
# Please put the [`best_model_semisupervised.pth`]( https://drive.google.com/file/d/1sE5sESUHj-1jSNS7_-waZ87LPreS-n4v/view?usp=drive_link ), the code files, and `data` to the working directory, `/content`.

# %%
# A quick command for import the code (you can skip this and upload them manually, too)
# !rm -rf ./*
# !git clone https://github.com/XiaoPanPanKevinPan/114-1-ML-HW4 --depth 1
# !mv 114-1-ML-HW4/* .

# %%
# A quick command for Kaggle download; get your token according to the docs
# https://github.com/Kaggle/kaggle-api/blob/3f8e54c5dc1121dd09be83f2ad607771b31b7457/docs/README.md#api-credentials
# !pip install kaggle --upgrade
# !env KAGGLE_API_TOKEN=YOUR_TOKEN_HERE kaggle competitions download -c nycu-114-1-introduction-to-machine-learning-hw-4

# %%
# A quick command for unzipping the data
# !unzip nycu-114-1-introduction-to-machine-learning-hw-4.zip

# %%
# Test if all files appear; should be no error and numbers should met
# !ls best_model_semisupervised.pth CNN.py inference.py main.py run_trainning.py semi_supervised.py threshold_finder.py utils.py
# !ls data
# !ls data/test | wc -l # should be 16753
# !ls data/train/generated | wc -l # should be 19188
# !ls data/train/real | wc -l # should be 22386
# !ls data/unlabeled | wc -l # should also be 22386

# %% [markdown]
# ### Step 2: Install Necessary Packages
# Please install the packages with the command line below. If you get a different version of CUDA, you may want to install `torch` and `torchvision` with [a different command]( https://pytorch.org/get-started/previous-versions/ ). It is tested that, `torch.version.cuda == "12.6"` can work well here.

# %%
# !pip install torch torchvision pandas loguru tqdm matplotlib scikit-learn pillow numpy
# alternatively, run `!pip install -r requirements3_12.txt`

# %% [markdown]
# ---
# Let's check the Torch's cuda version. It shouldn't be too new than CUDA 12.4 (12.6 is acceptable); otherwise, you should try to use the alternative command above.

# %%
import torch
torch.version.cuda

# %% [markdown]
# ## 2. Inference
#
# Please execute the code below. The output should be at `submission_semisupervised.csv`.

# %%
# !python inference.py --preset 3

# %% [markdown]
# ## 3. Checksum
# The checksum should be `c48d9a805aa04c77d474bf4494d28bb5`, which is the same as my submission with a public score of "0.99326".

# %%
# !md5sum submission_semisupervised.csv
